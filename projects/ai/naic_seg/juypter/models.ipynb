# %%
import pandas as pd
import qgrid
import gezi

# %%
root = '../working/v3'

# %%
# !ls ../working/v3

# %%
df = gezi.gen_metrics_df(root)

# %%
df[df.step==11].sort_values('FWIoU', ascending=False)[['FWIoU', 'Loss', 'model']].head(20)
# Out:
#      FWIoU    Loss                                              model
# 10  0.8014  0.3860        bonlime.DeeplabV3Plus.xception.slr.vflip025
# 10  0.8008  0.3845                             sm.Unet.efficientnetb7
# 10  0.8004  0.3586                     sm.Unet.efficientnetb4.vflip01
# 10  0.7997  0.3931            bonlime.DeeplabV3Plus.xception.vflip025
# 10  0.7995  0.3677  bonlime.DeeplabV3Plus.xception.slr.vflip025.scale
# 10  0.7988  0.3856                             sm.Unet.efficientnetb4
# 10  0.7986  0.3620            sm.Unet.efficientnetb4.vflip025.50epoch
# 10  0.7986  0.3899                             sm.Unet.efficientnetb5
# 10  0.7985  0.3966                    sm.Unet.efficientnetb7.100epoch
# 10  0.7976  0.3778                        sm.Unet.efficientnetb4.scse
# 10  0.7975  0.3858                         sm.Unet.efficientnetb4.ks3
# 10  0.7969  0.3808  bonlime.DeeplabV3Plus.xception.slr.vflip025.rot01
# ...

# %%
df[df.step==11].sort_values('Loss', ascending=True)[['FWIoU', 'Loss', 'model']].head(20)
# Out:
#      FWIoU    Loss                                              model
# 10  0.7961  0.3510                          sm.Unet.scale.50epoch.ks3
# 10  0.7939  0.3533                          sm.Unet.scale.50epoch.ks1
# 10  0.8004  0.3586                     sm.Unet.efficientnetb4.vflip01
# 10  0.7915  0.3587                             sm.Unet.scale.100epoch
# 10  0.7986  0.3620            sm.Unet.efficientnetb4.vflip025.50epoch
# 10  0.7907  0.3656                         sm.Unet.slr.scale.100epoch
# 10  0.7995  0.3677  bonlime.DeeplabV3Plus.xception.slr.vflip025.scale
# 10  0.7976  0.3778                        sm.Unet.efficientnetb4.scse
# 10  0.7650  0.3790                           sm.PSPNet.efficientnetb4
# 10  0.7969  0.3808  bonlime.DeeplabV3Plus.xception.slr.vflip025.rot01
# 10  0.8008  0.3845                             sm.Unet.efficientnetb7
# 10  0.7988  0.3856                             sm.Unet.efficientnetb4
# ...

# %%
df[df.step==21].sort_values('FWIoU', ascending=False)[['FWIoU', 'Loss', 'model']].head(20)
# Out:
#      FWIoU    Loss                                         model
# 20  0.8089  0.4020               sm.Unet.efficientnetb4.vflip025
# 20  0.8054  0.4661               sm.Unet.efficientnetb7.100epoch
# 20  0.8046  0.4418          sm.Unet.efficientnetb4.100epoch.run2
# 20  0.8029  0.4830               sm.unet.efficientnetb4.100epoch
# 20  0.7938  0.6377  bonlime.DeeplabV3Plus.xception.100epoch.run2
# 20  0.7244  0.4488                        sm-pspnet2-pad.50epoch
# 20  0.6786  0.5404                                   sm-baseline

# %%
df[df.step==21].sort_values('Loss', ascending=True)[['FWIoU', 'Loss', 'model']].head(20)
# Out:
#      FWIoU    Loss                                         model
# 20  0.8089  0.4020               sm.Unet.efficientnetb4.vflip025
# 20  0.8046  0.4418          sm.Unet.efficientnetb4.100epoch.run2
# 20  0.7244  0.4488                        sm-pspnet2-pad.50epoch
# 20  0.8054  0.4661               sm.Unet.efficientnetb7.100epoch
# 20  0.8029  0.4830               sm.unet.efficientnetb4.100epoch
# 20  0.6786  0.5404                                   sm-baseline
# 20  0.7938  0.6377  bonlime.DeeplabV3Plus.xception.100epoch.run2

# %% [markdown]
# # ensemble models
# ------100 epoch model
# 1. sm.Unet.efficientnetb7.100epoch                    0.8071  0.4559    tta h     ori  0.8054  0.4661
# 2. sm.Unet.efficientnetb4.vflip025                    0.8112  0.3902    tta h+v        0.8089  0.4020
# ------50 epoch model
# 3. bonlime.DeeplabV3Plus.xception.slr.vflip025        0.8088   0.3569    tta h+v  ori  0.8014  0.386
# 4. bonlime.DeeplabV3Plus.xception.slr.vflip025.scale  0.80727  0.3457    tta h+v       0.7995  0.3677
#
# # dump graph
# sh ./train/v3/eval-tta.sh --model=sm.Unet --backbone=efficientnetb7 --mn=sm.Unet.efficientnetb7.100epoch --steps=-1
# sh ./train/v3/eval-tta.sh --model=sm.Unet --backbone=efficientnetb4 --mn=sm.Unet.efficientnetb4.vflip025 --tta_fns=flip_left_right,flip_up_down --steps=-1
#
# sh ./train/v3/eval-tta.sh --mn=bonlime.DeeplabV3Plus.xception.slr.vflip025 --model=bonlime.DeeplabV3Plus --backbone=xception --tta_fns=flip_left_right,flip_up_down --steps=-1
# sh ./train/v3/eval-tta.sh --mn=bonlime.DeeplabV3Plus.xception.slr.vflip025.scale --model=bonlime.DeeplabV3Plus --backbone=xception --tta_fns=flip_left_right,flip_up_down --steps=-1
#
# # test graph eval
# sh ./train/v3/eval.sh --mn=sm.Unet.efficientnetb7.100epoch
# 313/313 [==============================] - 181s 577ms/step - loss: 0.4559 - FWIoU: 0.8072 - MIoU: 0.8010 - ACC/pixel: 0.8917 - ACC/class: 0.8872
# 2020-10-11 22:06:21 0:03:43 water    |true:0.1112 pred:0.1117 acc:0.9489 recall:0.9535 iou:0.9070 fwiou:0.9172|
# 2020-10-11 22:06:21 0:03:43 track    |true:0.0623 pred:0.0617 acc:0.8749 recall:0.8658 iou:0.7705 fwiou:0.8855|
# 2020-10-11 22:06:21 0:03:43 build    |true:0.1843 pred:0.1867 acc:0.9273 recall:0.9394 iou:0.8750 fwiou:0.8156|
# 2020-10-11 22:06:21 0:03:43 arable   |true:0.1636 pred:0.1659 acc:0.8496 recall:0.8617 iou:0.7476 fwiou:0.6697|
# 2020-10-11 22:06:21 0:03:43 grass    |true:0.0858 pred:0.0852 acc:0.8576 recall:0.8510 iou:0.7456 fwiou:0.8254|
# 2020-10-11 22:06:21 0:03:43 forest   |true:0.1556 pred:0.1551 acc:0.9369 recall:0.9343 iou:0.8791 fwiou:0.8495|
# 2020-10-11 22:06:21 0:03:43 bare     |true:0.0497 pred:0.0493 acc:0.8645 recall:0.8565 iou:0.7551 fwiou:0.9026|
# 2020-10-11 22:06:21 0:03:43 other    |true:0.1874 pred:0.1843 acc:0.8495 recall:0.8356 iou:0.7278 fwiou:0.5919|
#
# sh ./train/v3/eval.sh --mn=sm.Unet.efficientnetb4.vflip025  (online FWIoU )
# 313/313 [==============================] - 123s 394ms/step - loss: 0.3902 - FWIoU: 0.8112 - MIoU: 0.8045 - ACC/pixel: 0.8943 - ACC/class: 0.8890
# 2020-10-11 22:09:10 0:02:38 water    |true:0.1112 pred:0.1116 acc:0.9502 recall:0.9535 iou:0.9082 fwiou:0.9183|
# 2020-10-11 22:09:10 0:02:38 track    |true:0.0623 pred:0.0613 acc:0.8811 recall:0.8661 iou:0.7755 fwiou:0.8880|
# 2020-10-11 22:09:10 0:02:38 build    |true:0.1843 pred:0.1866 acc:0.9282 recall:0.9399 iou:0.8762 fwiou:0.8175|
# 2020-10-11 22:09:10 0:02:38 arable   |true:0.1636 pred:0.1664 acc:0.8517 recall:0.8665 iou:0.7530 fwiou:0.6767|
# 2020-10-11 22:09:10 0:02:38 grass    |true:0.0858 pred:0.0849 acc:0.8606 recall:0.8513 iou:0.7481 fwiou:0.8270|
# 2020-10-11 22:09:10 0:02:38 forest   |true:0.1556 pred:0.1552 acc:0.9378 recall:0.9355 iou:0.8808 fwiou:0.8516|
# 2020-10-11 22:09:10 0:02:38 bare     |true:0.0497 pred:0.0491 acc:0.8664 recall:0.8561 iou:0.7563 fwiou:0.9030|
# 2020-10-11 22:09:10 0:02:38 other    |true:0.1874 pred:0.1848 acc:0.8552 recall:0.8434 iou:0.7380 fwiou:0.6071|
#
# sh ./train/v3/eval.sh --mn=bonlime.DeeplabV3Plus.xception.slr.vflip025 (online FWIoU )  deep lab infer 需要bs 16 32OOM
# 313/313 [==============================] - 244s 780ms/step - loss: 0.3569 - FWIoU: 0.8088 - MIoU: 0.8019 - ACC/pixel: 0.8928 - ACC/class: 0.8861
# 2020-10-11 22:15:29 0:04:37 water    |true:0.1112 pred:0.1114 acc:0.9499 recall:0.9519 iou:0.9064 fwiou:0.9168|
# 2020-10-11 22:15:29 0:04:37 track    |true:0.0623 pred:0.0606 acc:0.8800 recall:0.8556 iou:0.7662 fwiou:0.8834|
# 2020-10-11 22:15:29 0:04:37 build    |true:0.1843 pred:0.1866 acc:0.9286 recall:0.9401 iou:0.8767 fwiou:0.8182|
# 2020-10-11 22:15:29 0:04:37 arable   |true:0.1636 pred:0.1666 acc:0.8506 recall:0.8664 iou:0.7520 fwiou:0.6755|
# 2020-10-11 22:15:29 0:04:37 grass    |true:0.0858 pred:0.0841 acc:0.8602 recall:0.8434 iou:0.7417 fwiou:0.8226|
# 2020-10-11 22:15:29 0:04:37 forest   |true:0.1556 pred:0.1555 acc:0.9360 recall:0.9354 iou:0.8792 fwiou:0.8497|
# 2020-10-11 22:15:29 0:04:37 bare     |true:0.0497 pred:0.0484 acc:0.8756 recall:0.8512 iou:0.7594 fwiou:0.9043|
# 2020-10-11 22:15:29 0:04:37 other    |true:0.1874 pred:0.1868 acc:0.8477 recall:0.8447 iou:0.7334 fwiou:0.6002|
#
# sh ./train/v3/eval.sh --mn=bonlime.DeeplabV3Plus.xception.slr.vflip025.scale
# 313/313 [==============================] - 244s 781ms/step - loss: 0.3457 - FWIoU: 0.8073 - MIoU: 0.8000 - ACC/pixel: 0.8919 - ACC/class: 0.8853
# 2020-10-11 22:25:18 0:04:38 water    |true:0.1112 pred:0.1114 acc:0.9501 recall:0.9520 iou:0.9067 fwiou:0.9170|
# 2020-10-11 22:25:18 0:04:38 track    |true:0.0623 pred:0.0604 acc:0.8760 recall:0.8492 iou:0.7581 fwiou:0.8793|
# 2020-10-11 22:25:18 0:04:38 build    |true:0.1843 pred:0.1874 acc:0.9238 recall:0.9393 iou:0.8717 fwiou:0.8108|
# 2020-10-11 22:25:18 0:04:38 arable   |true:0.1636 pred:0.1660 acc:0.8532 recall:0.8660 iou:0.7537 fwiou:0.6776|
# 2020-10-11 22:25:18 0:04:38 grass    |true:0.0858 pred:0.0842 acc:0.8636 recall:0.8470 iou:0.7470 fwiou:0.8263|
# 2020-10-11 22:25:18 0:04:38 forest   |true:0.1556 pred:0.1556 acc:0.9333 recall:0.9332 iou:0.8748 fwiou:0.8442|
# 2020-10-11 22:25:18 0:04:38 bare     |true:0.0497 pred:0.0489 acc:0.8669 recall:0.8528 iou:0.7541 fwiou:0.9021|
# 2020-10-11 22:25:18 0:04:38 other    |true:0.1874 pred:0.1860 acc:0.8495 recall:0.8433 iou:0.7337 fwiou:0.6008|

# %% [markdown]
# # 100 轮模型 ensemble
# sh ./train/v3/eval.sh --mnames=sm.Unet.efficientnetb7.100epoch,sm.Unet.efficientnetb4.vflip025 --mn=emsemble.100epoch
# 313/313 [==============================] - 298s 951ms/step - loss: 0.3740 - FWIoU: 0.8208 - MIoU: 0.8151 - ACC/pixel: 0.9002 - ACC/class: 0.8953
# 2020-10-11 22:24:11 0:06:27 water    |true:0.1112 pred:0.1116 acc:0.9523 recall:0.9561 iou:0.9124 fwiou:0.9221|
# 2020-10-11 22:24:11 0:06:27 track    |true:0.0623 pred:0.0612 acc:0.8902 recall:0.8737 iou:0.7887 fwiou:0.8946|
# 2020-10-11 22:24:11 0:06:27 build    |true:0.1843 pred:0.1871 acc:0.9313 recall:0.9452 iou:0.8836 fwiou:0.8283|
# 2020-10-11 22:24:11 0:06:27 arable   |true:0.1636 pred:0.1663 acc:0.8574 recall:0.8715 iou:0.7612 fwiou:0.6874|
# 2020-10-11 22:24:11 0:06:27 grass    |true:0.0858 pred:0.0846 acc:0.8719 recall:0.8593 iou:0.7630 fwiou:0.8373|
# 2020-10-11 22:24:11 0:06:27 forest   |true:0.1556 pred:0.1550 acc:0.9435 recall:0.9402 iou:0.8901 fwiou:0.8632|
# 2020-10-11 22:24:11 0:06:27 bare     |true:0.0497 pred:0.0489 acc:0.8794 recall:0.8649 iou:0.7732 fwiou:0.9098|
# 2020-10-11 22:24:11 0:06:27 other    |true:0.1874 pred:0.1853 acc:0.8612 recall:0.8515 iou:0.7488 fwiou:0.6233|

# %% [markdown]
# # 50轮模型 ensmeble
# sh ./train/v3/eval.sh --mnames=bonlime.DeeplabV3Plus.xception.slr.vflip025,bonlime.DeeplabV3Plus.xception.slr.vflip025.scale --mn=ensemble.50epoch
# 313/313 [==============================] - 482s 2s/step - loss: 0.3227 - FWIoU: 0.8178 - MIoU: 0.8113 - ACC/pixel: 0.8984 - ACC/class: 0.8919
# 2020-10-11 22:27:28 0:09:21 water    |true:0.1112 pred:0.1114 acc:0.9524 recall:0.9540 iou:0.9106 fwiou:0.9204|
# 2020-10-11 22:27:28 0:09:21 track    |true:0.0623 pred:0.0603 acc:0.8880 recall:0.8590 iou:0.7751 fwiou:0.8878|
# 2020-10-11 22:27:28 0:09:21 build    |true:0.1843 pred:0.1872 acc:0.9293 recall:0.9439 iou:0.8807 fwiou:0.8241|
# 2020-10-11 22:27:28 0:09:21 arable   |true:0.1636 pred:0.1662 acc:0.8581 recall:0.8718 iou:0.7620 fwiou:0.6885|
# 2020-10-11 22:27:28 0:09:21 grass    |true:0.0858 pred:0.0837 acc:0.8732 recall:0.8517 iou:0.7579 fwiou:0.8338|
# 2020-10-11 22:27:28 0:09:21 forest   |true:0.1556 pred:0.1556 acc:0.9395 recall:0.9396 iou:0.8860 fwiou:0.8581|
# 2020-10-11 22:27:28 0:09:21 bare     |true:0.0497 pred:0.0486 acc:0.8812 recall:0.8609 iou:0.7714 fwiou:0.9090|
# 2020-10-11 22:27:28 0:09:21 other    |true:0.1874 pred:0.1870 acc:0.8561 recall:0.8541 iou:0.7469 fwiou:0.6205|

# %% [markdown]
# # 4个模型 ensemble
# sh ./train/v3/eval.sh --mnames=sm.Unet.efficientnetb7.100epoch,sm.Unet.efficientnetb4.vflip025,bonlime.DeeplabV3Plus.xception.slr.vflip025,bonlime.DeeplabV3Plus.xception.slr.vflip025.scale --mn=ensemble.4 --batch_size=16 (32oom)
#
# 313/313 [==============================] - 424s 1s/step - loss: 0.3212 - FWIoU: 0.8267 - MIoU: 0.8212 - ACC/pixel: 0.9039 - ACC/class: 0.8982
# 2020-10-11 22:43:16 0:13:41 water    |true:0.1112 pred:0.1115 acc:0.9541 recall:0.9568 iou:0.9147 fwiou:0.9241|
# 2020-10-11 22:43:16 0:13:41 track    |true:0.0623 pred:0.0606 acc:0.8977 recall:0.8729 iou:0.7939 fwiou:0.8972|
# 2020-10-11 22:43:16 0:13:41 build    |true:0.1843 pred:0.1874 acc:0.9326 recall:0.9482 iou:0.8875 fwiou:0.8341|
# 2020-10-11 22:43:16 0:13:41 arable   |true:0.1636 pred:0.1663 acc:0.8617 recall:0.8762 iou:0.7681 fwiou:0.6965|
# 2020-10-11 22:43:16 0:13:41 grass    |true:0.0858 pred:0.0840 acc:0.8793 recall:0.8607 iou:0.7698 fwiou:0.8419|
# 2020-10-11 22:43:16 0:13:41 forest   |true:0.1556 pred:0.1551 acc:0.9455 recall:0.9423 iou:0.8937 fwiou:0.8678|
# 2020-10-11 22:43:16 0:13:41 bare     |true:0.0497 pred:0.0486 acc:0.8884 recall:0.8683 iou:0.7829 fwiou:0.9136|
# 2020-10-11 22:43:16 0:13:41 other    |true:0.1874 pred:0.1865 acc:0.8650 recall:0.8606 iou:0.7587 fwiou:0.6382|
#
# prun.py 8 sh ./train/v3/eval.sh --mnames=sm.Unet.efficientnetb7.100epoch,sm.Unet.efficientnetb4.vflip025,bonlime.DeeplabV3Plus.xception.slr.vflip025,bonlime.DeeplabV3Plus.xception.slr.vflip025.scale --mn=ensemble.4 --mode=test --batch_size=16
#
# using 20min

# %% [markdown]
# # another 100 epoch with scale(rot)
# 加了rot会降低fiou 但是降低loss 可以作为集成降低风险
# ori 0.8064 0.3851
# sh ./train/v3/eval.sh --model=sm.Unet --backbone=efficientnetb4 --mn=sm.Unet.scale.100epoch --tta_fns=flip_left_right,flip_up_down --steps=-1
#
# 313/313 [==============================] - 124s 396ms/step - loss: 0.3768 - FWIoU: 0.8085 - MIoU: 0.8015 - ACC/pixel: 0.8926 - ACC/class: 0.8874
# 2020-10-11 22:37:37 0:02:40 water    |true:0.1112 pred:0.1119 acc:0.9484 recall:0.9542 iou:0.9071 fwiou:0.9174|
# 2020-10-11 22:37:37 0:02:40 track    |true:0.0623 pred:0.0618 acc:0.8729 recall:0.8650 iou:0.7683 fwiou:0.8844|
# 2020-10-11 22:37:37 0:02:40 build    |true:0.1843 pred:0.1866 acc:0.9273 recall:0.9385 iou:0.8742 fwiou:0.8144|
# 2020-10-11 22:37:37 0:02:40 arable   |true:0.1636 pred:0.1658 acc:0.8528 recall:0.8645 iou:0.7522 fwiou:0.6758|
# 2020-10-11 22:37:37 0:02:40 grass    |true:0.0858 pred:0.0848 acc:0.8600 recall:0.8502 iou:0.7468 fwiou:0.8262|
# 2020-10-11 22:37:37 0:02:40 forest   |true:0.1556 pred:0.1552 acc:0.9370 recall:0.9345 iou:0.8792 fwiou:0.8496|
# 2020-10-11 22:37:37 0:02:40 bare     |true:0.0497 pred:0.0490 acc:0.8646 recall:0.8523 iou:0.7519 fwiou:0.9013|
# 2020-10-11 22:37:37 0:02:40 other    |true:0.1874 pred:0.1849 acc:0.8514 recall:0.8401 iou:0.7326 fwiou:0.5991|
#
# sh ./train/v3/eval.sh --mnames=sm.Unet.efficientnetb7.100epoch,sm.Unet.efficientnetb4.vflip025,bonlime.DeeplabV3Plus.xception.slr.vflip025,bonlime.DeeplabV3Plus.xception.slr.vflip025.scale,sm.Unet.scale.100epoch --mn=ensemble.5 --batch_size=16 --gpus=2
#
# 313/313 [==============================] - 485s 2s/step - loss: 0.3153 - FWIoU: 0.8281 - MIoU: 0.8225 - ACC/pixel: 0.9047 - ACC/class: 0.8992
# 2020-10-11 22:58:58 0:17:16 water    |true:0.1112 pred:0.1116 acc:0.9540 recall:0.9572 iou:0.9150 fwiou:0.9244|
# 2020-10-11 22:58:58 0:17:16 track    |true:0.0623 pred:0.0607 acc:0.8982 recall:0.8748 iou:0.7959 fwiou:0.8982|
# 2020-10-11 22:58:58 0:17:16 build    |true:0.1843 pred:0.1872 acc:0.9338 recall:0.9485 iou:0.8887 fwiou:0.8359|
# 2020-10-11 22:58:58 0:17:16 arable   |true:0.1636 pred:0.1662 acc:0.8627 recall:0.8766 iou:0.7692 fwiou:0.6980|
# 2020-10-11 22:58:58 0:17:16 grass    |true:0.0858 pred:0.0841 acc:0.8800 recall:0.8620 iou:0.7714 fwiou:0.8430|
# 2020-10-11 22:58:58 0:17:16 forest   |true:0.1556 pred:0.1551 acc:0.9463 recall:0.9435 iou:0.8956 fwiou:0.8700|
# 2020-10-11 22:58:58 0:17:16 bare     |true:0.0497 pred:0.0486 acc:0.8888 recall:0.8688 iou:0.7836 fwiou:0.9139|
# 2020-10-11 22:58:58 0:17:16 other    |true:0.1874 pred:0.1864 acc:0.8665 recall:0.8620 iou:0.7609 fwiou:0.6415|
#
# prun.py 8 sh ./train/v3/eval.sh --mnames=sm.Unet.efficientnetb7.100epoch,sm.Unet.efficientnetb4.vflip025,bonlime.DeeplabV3Plus.xception.slr.vflip025,bonlime.DeeplabV3Plus.xception.slr.vflip025.scale,sm.Unet.scale.100epoch --mn=ensemble.5 --batch_size=16 --mode=test

# %% [markdown]
# # 100 epoch  deeplab
# bonlime.DeeplabV3Plus.xception.slr.scale.100epoch  'Loss': 0.4234224855899811, 'FWIoU': 0.802851080506234
# sh ./train/v3/eval-tta.sh --mn=bonlime.DeeplabV3Plus.xception.slr.scale.100epoch --model=bonlime.DeeplabV3Plus --backbone=xception --tta_fns=flip_left_right,flip_up_down --steps=-1
# sh ./train/v3/eval.sh --mn=bonlime.DeeplabV3Plus.xception.slr.scale.100epoch
# 313/313 [==============================] - 248s 791ms/step - loss: 0.3940 - FWIoU: 0.8103 - MIoU: 0.8032 - ACC/pixel: 0.8938 - ACC/class: 0.8877
# 2020-10-12 04:45:00 0:04:46 water    |true:0.1112 pred:0.1109 acc:0.9503 recall:0.9480 iou:0.9032 fwiou:0.9139|
# 2020-10-12 04:45:00 0:04:46 track    |true:0.0623 pred:0.0609 acc:0.8794 recall:0.8587 iou:0.7682 fwiou:0.8844|
# 2020-10-12 04:45:00 0:04:46 build    |true:0.1843 pred:0.1869 acc:0.9277 recall:0.9405 iou:0.8762 fwiou:0.8175|
# 2020-10-12 04:45:00 0:04:46 arable   |true:0.1636 pred:0.1661 acc:0.8525 recall:0.8654 iou:0.7527 fwiou:0.6763|
# 2020-10-12 04:45:00 0:04:46 grass    |true:0.0858 pred:0.0841 acc:0.8645 recall:0.8470 iou:0.7478 fwiou:0.8268|
# 2020-10-12 04:45:00 0:04:46 forest   |true:0.1556 pred:0.1558 acc:0.9365 recall:0.9378 iou:0.8817 fwiou:0.8528|
# 2020-10-12 04:45:00 0:04:46 bare     |true:0.0497 pred:0.0492 acc:0.8675 recall:0.8574 iou:0.7581 fwiou:0.9037|
# 2020-10-12 04:45:00 0:04:46 other    |true:0.1874 pred:0.1862 acc:0.8519 recall:0.8465 iou:0.7379 fwiou:0.6070|
#
# sh ./train/v3/eval.sh --mnames=sm.Unet.efficientnetb7.100epoch,sm.Unet.efficientnetb4.vflip025,bonlime.DeeplabV3Plus.xception.slr.vflip025,bonlime.DeeplabV3Plus.xception.slr.vflip025.scale,sm.Unet.scale.100epoch,bonlime.DeeplabV3Plus.xception.slr.scale.100epoch --mn=ensemble.6 --batch_size=16 --gpus=2
# 2个gpu即可 8个这里启动太慢了
#
# 313/313 [==============================] - 603s 2s/step - loss: 0.3145 - FWIoU: 0.8292 - MIoU: 0.8238 - ACC/pixel: 0.9054 - ACC/class: 0.8998
# 2020-10-12 05:49:25 0:19:44 water    |true:0.1112 pred:0.1116 acc:0.9541 recall:0.9572 iou:0.9150 fwiou:0.9244|
# 2020-10-12 05:49:25 0:19:44 track    |true:0.0623 pred:0.0606 acc:0.8999 recall:0.8746 iou:0.7970 fwiou:0.8988|
# 2020-10-12 05:49:25 0:19:44 build    |true:0.1843 pred:0.1873 acc:0.9340 recall:0.9490 iou:0.8894 fwiou:0.8368|
# 2020-10-12 05:49:25 0:19:44 arable   |true:0.1636 pred:0.1662 acc:0.8635 recall:0.8771 iou:0.7703 fwiou:0.6994|
# 2020-10-12 05:49:25 0:19:44 grass    |true:0.0858 pred:0.0840 acc:0.8815 recall:0.8623 iou:0.7727 fwiou:0.8440|
# 2020-10-12 05:49:25 0:19:44 forest   |true:0.1556 pred:0.1552 acc:0.9468 recall:0.9443 iou:0.8967 fwiou:0.8715|
# 2020-10-12 05:49:25 0:19:44 bare     |true:0.0497 pred:0.0486 acc:0.8910 recall:0.8705 iou:0.7867 fwiou:0.9151|
# 2020-10-12 05:49:25 0:19:44 other    |true:0.1874 pred:0.1867 acc:0.8668 recall:0.8633 iou:0.7622 fwiou:0.6434|
#
# prun.py 8 sh ./train/v3/eval.sh --mnames=sm.Unet.efficientnetb7.100epoch,sm.Unet.efficientnetb4.vflip025,bonlime.DeeplabV3Plus.xception.slr.vflip025,bonlime.DeeplabV3Plus.xception.slr.vflip025.scale,sm.Unet.scale.100epoch,bonlime.DeeplabV3Plus.xception.slr.scale.100epoch --mn=ensemble.6 --batch_size=16 --mode=test
